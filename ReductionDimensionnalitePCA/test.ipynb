# %% [markdown]
# ### Importer des bibliothèques

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# ### Charger et préparer les données
# Pour cet exemple, nous utiliserons le fameux Ensemble de données sur l'iris, qui contient des informations sur la taille des pétales et des sépales de différentes espèces d'iris. Nous chargeons et séparons les variables indépendantes :

# %%
from sklearn.datasets import load_iris

# Cargar datos
iris = load_iris()
X = iris.data

# %% [markdown]
# ### Standardiser les données
# La normalisation des données est essentielle en PCA, car elle garantit que chaque variable a une moyenne nulle et une variance unitaire, permettant de les analyser dans la même mesure.

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Appliquer la PCA et transformer les données
# Nous définissons le nombre de composants principaux souhaités et appliquons la PCA. Ici, nous réduisons l'assemblage à deux composants principaux pour faciliter la visualisation.

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# ### Afficher les données réduites
# Nous représentons les données dans un nuage de points, ce qui facilite l'identification des modèles et des groupes dans les données.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=iris.target, cmap='viridis')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.title('PCA de Iris Dataset')
plt.colorbar()
plt.show()
